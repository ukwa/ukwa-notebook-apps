# %% [markdown]
# Experimenting with Solr SQL
# ===========================
#
# This notebook is for experimenting with Solr's Parallel SQL interface, especially via an SQLAlchemy plugin so that it's exactly like normal SQL.
#
# Unfortunatley, current state of play is that Solr 6 does not cope with SQL queries on _aliases_, so it's not much use for text analysis right now.
#
# The SQL system does work okay for Solr 8, but the `SELECT *` logic seems to be a bit brittle (at least via the SQLAlchemy module).  It works pretty reliably if the fields are explicitly enumerated.

# %%
# !pip install sqlalchemy-solr
# Out:
# Requirement already satisfied: sqlalchemy-solr in /opt/conda/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from sqlalchemy-solr) (1.17.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from sqlalchemy-solr) (2.22.0)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.7/site-packages (from sqlalchemy-solr) (1.3.11)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from sqlalchemy-solr) (0.25.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->sqlalchemy-solr) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->sqlalchemy-solr) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->sqlalchemy-solr) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->sqlalchemy-solr) (1.25.7)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas->sqlalchemy-solr) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->sqlalchemy-solr) (2019.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas->sqlalchemy-solr) (1.13.0)

# %%
from sqlalchemy import create_engine

fc = 'NPLD-FC2017-20190228'

engine = create_engine('solr://solr.api.wa.bl.uk:80/solr/%s' % fc)

# Unfortunately, for Solr 6, we can't query aliases and all fields * leads to class cast exceptions!
# (java.lang.Long cannot be cast to java.lang.String)
rows = engine.execute("SELECT id,url,wayback_date FROM `%s` LIMIT 1" % fc)

for r in rows:
    for column, value in r.items():
        print(column, value)
# Out:
# ************************************
# Query: SELECT id,url,wayback_date FROM `NPLD-FC2017-20190228` LIMIT 1
# ************************************
# id 20171225120530/r1upsuMttEfpjRI2R4rN7Q==
# url http://www.newquayvoice.co.uk/news/5/article/2920/
# wayback_date 20171225120530
# ************************************
# Catched StopIteration in fetchone
# ************************************

# %%
#rows = engine.execute("SELECT id,url FROM `NPLD-FC2017-20190228` WHERE (host:'theguardian.com' OR host:'independent.co.uk' OR host:'dailymail.co.uk' OR host:'express.co.uk' OR host:'thesun.co.uk' OR host:'mirror.co.uk' OR host:'dailystar.co.uk') AND ((title:meghan AND title:harry) OR (title:meghan AND title:markle)) LIMIT 1")
rows = engine.execute("SELECT id,url,title,host FROM `NPLD-FC2017-20190228` WHERE host = '(theguardian.com independent.co.uk dailymail.co.uk express.co.uk thesun.co.uk mirror.co.uk dailystar.co.uk)' AND ((title = 'meghan' AND title = 'markle') OR (title = 'meghan' AND title = 'harry')) ORDER BY crawl_date LIMIT 1")

for r in rows:
    for column, value in r.items():
        print(column, value)
# Out:
# ************************************
# Query: SELECT id,url,title,host FROM `NPLD-FC2017-20190228` WHERE host = '(theguardian.com independent.co.uk dailymail.co.uk express.co.uk thesun.co.uk mirror.co.uk dailystar.co.uk)' AND ((title = 'meghan' AND title = 'markle') OR (title = 'meghan' AND title = 'harry')) ORDER BY crawl_date LIMIT 1
# ************************************
# id 20170101102033/lhGw4C4wmG+0iFG0t7JrFw==
# url http://www.dailymail.co.uk/tvshowbiz/article-3976578/amp/Meghan-Markle-enjoys-cocktails-Quantico-star-Priyanka-Chopra-Prince-Harry-tours-Caribbean.html
# title Meghan Markle enjoys cocktails with Quantico's Priyanka Chopra while Prince Harry tours
# host dailymail.co.uk
# ************************************
# Catched StopIteration in fetchone
# ************************************

# %%
sql_df = pd.read_sql_query(
    "SELECT id,url,title,host,crawl_date FROM `NPLD-FC2017-20190228` WHERE host = '(theguardian.com independent.co.uk dailymail.co.uk express.co.uk thesun.co.uk mirror.co.uk dailystar.co.uk)' AND ((title = 'meghan' AND title = 'markle') OR (title = 'meghan' AND title = 'harry')) ORDER BY crawl_date LIMIT 100000",
    con=engine
)

sql_df
# Out:
# ************************************
# Query: SELECT id,url,title,host,crawl_date FROM `NPLD-FC2017-20190228` WHERE host = '(theguardian.com independent.co.uk dailymail.co.uk express.co.uk thesun.co.uk mirror.co.uk dailystar.co.uk)' AND ((title = 'meghan' AND title = 'markle') OR (title = 'meghan' AND title = 'harry')) ORDER BY crawl_date LIMIT 100000
# ************************************
#                                             id  \
# 0      20170101102033/lhGw4C4wmG+0iFG0t7JrFw==
# 1      20170101102049//M3a8PfNIu5zNH26wfStXA==
# 2      20170101102057/Erluxdjjqr/jNL4hNzha4A==
# 3      20170101102101/z6CUHQC6PS+SWkzOnV6hLw==
# 4      20170101102123/Vs9UbyshtSk1D9ZNIyRFCA==
# ...                                        ...
# 21051  20171227215813/rt9ttovXyXjBwGOzBKCWgg==
# 21052  20171227215854/ZxKG1KVJAy95739ySnIbxg==
# 21053  20171227231231/V2VEliskxTDJbIqlCcsF7w==
# 21054  20171228022515/n/RUSr7G6FbUZuSljxsDew==
# 21055  20171228051104/jhk46gtxkCF6PdKDcih6eA==
#
#                                                      url  \
# 0      http://www.dailymail.co.uk/tvshowbiz/article-3...
# 1      http://www.dailymail.co.uk/news/article-392542...
# 2      http://www.dailymail.co.uk/news/article-402914...
# 3      http://www.dailymail.co.uk/news/article-402914...
# 4      http://www.dailymail.co.uk/news/article-396227...
# ...                                                  ...
# 21051  http://www.mirror.co.uk/news/uk-news/prince-ha...
# 21052  http://www.mirror.co.uk/3am/style/celebrity-fa...
# 21053  http://www.mirror.co.uk/3am/celebrity-news/por...
# 21054  http://www.mirror.co.uk/news/uk-news/meghan-ma...
# 21055  http://www.mirror.co.uk/3am/celebrity-news/pri...
#
#                                                    title             host  \
# 0      Meghan Markle enjoys cocktails with Quantico's...  dailymail.co.uk
# 1      Prince Harry's girlfriend Meghan Markle spotte...  dailymail.co.uk
# 2      Prince Harry and girlfriend Meghan Markle 'buy...  dailymail.co.uk
# 3      Prince Harry and girlfriend Meghan Markle 'buy...  dailymail.co.uk
# 4      Prince Harry's girlfriend Meghan Markle says s...  dailymail.co.uk
# ...                                                  ...              ...
# 21051  Prince Harry WON'T take part in the traditiona...     mirror.co.uk
# 21052  Meghan Markle is Hollywood perfection in £56,0...     mirror.co.uk
# 21053  Porn searches for Meghan Markle go through the...     mirror.co.uk
# 21054  Prince Harry reveals Meghan Markle's first Chr...     mirror.co.uk
# 21055  When are Prince Harry and Meghan Markle gettin...     mirror.co.uk
#
#                crawl_date
# 0     2017-01-01 10:20:33
# 1     2017-01-01 10:20:49
# 2     2017-01-01 10:20:57
# 3     2017-01-01 10:21:01
# 4     2017-01-01 10:21:23
# ...                   ...
# 21051 2017-12-27 21:58:13
# 21052 2017-12-27 21:58:54
# 21053 2017-12-27 23:12:31
# 21054 2017-12-28 02:25:15
# 21055 2017-12-28 05:11:04
#
# [21056 rows x 5 columns]

# %%
import sys
from sqlalchemy import create_engine
from sqlalchemy import inspect
import pandas as pd

pd.set_option('display.max_colwidth', -1)

def crawl_log_sql(sql_url='solr://dev1.n45.wa.bl.uk:8913/solr/crawl_log_fc'):
    return SolrSql(sql_url)


class SolrSql():
    
    def __init__(self, sql_url, fillna=''):
        self.sql_url = sql_url
        self.engine = create_engine(self.sql_url)
        self.fillna = fillna
        
    def columns(self):
        inspector = inspect(self.engine)

        cols = []
        for table_name in inspector.get_table_names():
            for column in inspector.get_columns(table_name):
                cols.append(column['name'])
                
        return cols

    def query(self, sql):
        try:
            sql_df = pd.read_sql_query(
                sql,
                con=self.engine
            )
        except Exception as e:
            print("%s: %s" % (e.__class__.__name__, e), file=sys.stderr)
            return None

        if self.fillna:
            sql_df.fillna(self.fillna, inplace=True)

        return sql_df

#crawl_log_sql("SELECT * FROM crawl_log_fc WHERE annotations = 'Q:serverMaxSuccessKb' ORDER BY log_timestamp DESC LIMIT 10")
logs = crawl_log_sql()
logs.query("SELECT * FROM crawl_log_fc WHERE mimetype LIKE 'image/*' ORDER BY `log_timestamp` DESC LIMIT 100")
# Out:
# ************************************
# Query: SELECT * FROM crawl_log_fc WHERE mimetype LIKE 'image/*' ORDER BY `log_timestamp` DESC LIMIT 100
# ************************************
#     dol   hop_path           log_timestamp  status_code  \
# 0  NaN   RLLLLLLL  2021-02-04 13:57:49.531 -5003
# 1  NaN   LLLEL     2021-02-04 13:57:49.529 -5003
# 2  NaN   NaN       2021-02-04 13:57:49.433  200
# 3  NaN   RLLLLLLE  2021-02-04 13:57:49.400 -5003
# 4  NaN   LE        2021-02-04 13:57:49.399  200
# ..  ..   ..                            ...  ...
# 95 NaN   LLLLEIIIX 2021-02-04 13:57:40.838 -5003
# 96 NaN   LLLLEIIIX 2021-02-04 13:57:40.729 -5003
# 97 NaN   RIII      2021-02-04 13:57:40.697  200
# 98 NaN   LLLLLLR   2021-02-04 13:57:40.694  200
# 99 NaN   LLLLEIIIX 2021-02-04 13:57:40.649 -5003
#
#                                                                               warc_filename  \
# 0   NaN
# 1   NaN
# 2   BL-NPLD-WEBRENDER-frequent-npld-20210119131039-20210204135046812-03619-n4o6ljbu.warc.gz
# 3   NaN
# 4   NaN
# ..  ...
# 95  NaN
# 96  NaN
# 97  NaN
# 98  NaN
# 99  NaN
#
#     warc_length           annotations                         content_digest  \
# 0  NaN           Q:serverMaxSuccessKb  NaN
# 1  NaN           Q:serverMaxSuccessKb  NaN
# 2   2295.0       NaN                   sha1:LCJKSW7MZUANWXCSTVZWFNEQUZUQG6G6
# 3  NaN           Q:serverMaxSuccessKb  NaN
# 4  NaN           NaN                   sha1:IUPDL5ISAUDVS6CHS6OB2RNVMB5QIXMX
# ..  ..           ...                                                     ...
# 95 NaN           Q:serverMaxSuccessKb  NaN
# 96 NaN           Q:serverMaxSuccessKb  NaN
# 97 NaN           NaN                   sha1:QMCIHKXWBR4IOP3ER3HF5U6HGSAP2NM7
# 98 NaN           NaN                   sha1:5FPEUN3T5XNNHYIGEJPXWZDU2OV2KZE6
# 99 NaN           Q:serverMaxSuccessKb  NaN
#
#                                                              source  \
# 0   tid:65152:https://londongreenleft.blogspot.co.uk/
# 1   tid:129958:https://podcasts.ox.ac.uk/mark-carney-climate-change
# 2   NaN
# 3   tid:65152:https://londongreenleft.blogspot.co.uk/
# 4   tid:117325:https://blogs.glowscotland.org.uk/gc/hillheadhigh/
# ..                                                            ...
# 95  tid:109300:https://www.express.co.uk/latest/coronavirus/
# 96  tid:109300:https://www.express.co.uk/latest/coronavirus/
# 97  tid:62987:http://www.celebsnow.co.uk/
# 98  tid:109600:https://acvo.org.uk/about/covid-19/
# 99  tid:109300:https://www.express.co.uk/latest/coronavirus/
#
#                                                                                                                                                                                                     via  \
# 0   https://londongreenleft.blogspot.com/2015/03/photos-peoples-climate-march-london.html?m=0
# 1   https://podcasts.ox.ac.uk/node/62668
# 2   NaN
# 3   https://londongreenleft.blogspot.com/2015/03/photos-peoples-climate-march-london.html?m=0
# 4   https://blogs.glowscotland.org.uk/gc/hillheadhigh/parent-zone/advice-and-support/substance-misuse/
# ..                                                                                                 ...
# 95  https://www.express.co.uk/videos/201911.xml
# 96  https://www.express.co.uk/videos/201911.xml
# 97  https://www.celebsnow.co.uk/sitemap.xml?yyyy=2016&mm=03
# 98  https://www.nhs.uk/service-search/other-services/Disambiguation/ResultView?locationId=1632&locationName=Bentworth&entityId=341&serviceName=Eating-disorder-support&latitude=51.158&longitude=-1.051
# 99  https://www.express.co.uk/videos/201911.xml
#
#     ...              start_time    crawler     size            _version_  \
# 0   ... NaT                      Heritrix  NaN       1691350466971041795
# 1   ... NaT                      Heritrix  NaN       1691350466971041794
# 2   ... 2021-02-04 13:56:19.836  WebRender NaN       1691350466971041793
# 3   ... NaT                      Heritrix  NaN       1691350466971041792
# 4   ... 2021-02-04 13:57:49.336  Heritrix   27154.0  1691350466969993220
# ..  ...                     ...       ...       ...                  ...
# 95  ... NaT                      Heritrix  NaN       1691350466951118850
# 96  ... NaT                      Heritrix  NaN       1691350466951118849
# 97  ... 2021-02-04 13:57:40.483  Heritrix   64904.0  1691350466951118848
# 98  ... 2021-02-04 13:57:40.205  Heritrix   49678.0  1691350466950070276
# 99  ... NaT                      Heritrix  NaN       1691350466950070275
#
#           launch_timestamp warc_type   mimetype wire_bytes  _query_ score
# 0  NaT                      NaN       unknown   NaN        NaN       1
# 1  NaT                      NaN       unknown   NaN        NaN       1
# 2  NaT                      response  NaN        1930.0    NaN       1
# 3  NaT                      NaN       unknown   NaN        NaN       1
# 4  NaT                      NaN       text/css  NaN        NaN       1
# ..  ..                      ...            ...   ..         ..      ..
# 95 NaT                      NaN       unknown   NaN        NaN       1
# 96 NaT                      NaN       unknown   NaN        NaN       1
# 97 2016-03-15 15:30:01.200  NaN       text/html NaN        NaN       1
# 98 NaT                      NaN       text/html NaN        NaN       1
# 99 NaT                      NaN       unknown   NaN        NaN       1
#
# [100 rows x 35 columns]

# %%
logs.query(
    "SELECT host, source, count(*) as urls \
    FROM crawl_log_fc \
    WHERE annotations = 'Q:serverMaxSuccessKb' \
    GROUP BY host, source \
    ORDER BY urls DESC \
    LIMIT 20"
)
# Out:
# ************************************
# Query: SELECT host, source, count(*) as urls     FROM crawl_log_fc     WHERE annotations = 'Q:serverMaxSuccessKb'     GROUP BY host, source     ORDER BY urls DESC     LIMIT 20
# ************************************
#                               host  \
# 0   storage.googleapis.com
# 1   cdn11.bigcommerce.com
# 2   www.legislation.gov.uk
# 3   i.dailymail.co.uk
# 4   i2-prod.grimsbytelegraph.co.uk
# 5   medium.com
# 6   deriv.nls.uk
# 7   thumbnailer.mixcloud.com
# 8   www.almos.org.uk
# 9   res.cloudinary.com
# 10  johnlewis.scene7.com
# 11  d2x51gyc4ptf2q.cloudfront.net
# 12  www.diydoctor.org.uk
# 13  cdn.shortpixel.ai
# 14  media.livehub.me
# 15  www.asos.com
# 16  hips.hearstapps.com
# 17  www.hulldailymail.co.uk
# 18  ksiegarniainternetowa.co.uk
# 19  www.autotrader.co.uk
#
#                                                                 source    urls
# 0   tid:95604:http://www.ercc.scot/                                     207396
# 1   tid:129806:https://www.scottsofstow.co.uk/                          192127
# 2   tid:96456:http://ukscblog.com/                                      124498
# 3   tid:109175:https://www.dailymail.co.uk/news/coronavirus/index.html  123462
# 4   tid:31421:http://www.grimsbytelegraph.co.uk/                        122552
# 5   tid:100481:https://medium.com/@ncb1947                              121702
# 6   tid:34936:https://orhighlights.wordpress.com/                       114637
# 7   tid:97162:https://www.mixcloud.com/                                 92439
# 8   tid:16876:http://www.almos.org.uk/                                  85113
# 9   tid:95238:https://www.waitrose.com/                                 84687
# 10  tid:12434:http://www.johnlewis.com/                                 83076
# 11  tid:66901:https://www.givemesport.com/                              75674
# 12  tid:69934:https://www.diydoctor.org.uk/forum                        74806
# 13  tid:130012:https://bridgewoodandneitzert.london/                    68591
# 14  tid:129894:http://www.godisinthetvzine.co.uk/                       68042
# 15  tid:85790:https://www.asos.com/                                     66259
# 16  tid:54549:http://www.digitalspy.com/                                65766
# 17  tid:31434:http://www.hulldailymail.co.uk/                           61679
# 18  tid:114309:https://ksiegarniainternetowa.co.uk/                     60123
# 19  tid:68200:https://www.thestudentroom.co.uk/                         59784

# %%
tracking = SolrSql('solr://solr8.api.wa.bl.uk:80/solr/tracking')
print(tracking.columns())

sql_df = tracking.query("SELECT * FROM tracking WHERE kind_s = 'warcs' LIMIT 2")

sql_df
# Out:
# ['_root_', '_version_', 'cdx_index_ss', 'cdx_records_checked_i', 'cdx_records_found_i', 'collection_s', 'file_ext_s', 'file_name_s', 'file_path_s', 'file_size_l', 'hdfs_group_s', 'hdfs_replicas_i', 'hdfs_user_s', 'id', 'job_s', 'kind_s', 'layout_s', 'modified_at_dt', 'permissions_s', 'recognised_b', 'refresh_date_dt', 'stream_s', 'timestamp_dt', 'year_i']
# ************************************
# Query: SELECT * FROM tracking WHERE kind_s = 'warcs' LIMIT 2
# ************************************
#                         file_name_s  _root_ hdfs_user_s     stream_s  \
# 0  www.bl.uk-20150814093821.warc.gz NaN      hdfs        webrecorder
# 1  www.bl.uk-20150814094134.warc.gz NaN      hdfs        webrecorder
#
#                                                                        file_path_s  \
# 0  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814093821.warc.gz
# 1  /1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094134.warc.gz
#
#    cdx_records_found_i  year_i      modified_at_dt recognised_b  file_size_l  \
# 0 NaN                   2016   2016-12-30 11:59:00  true         12729735
# 1 NaN                   2016   2016-12-30 11:59:00  true         95733865
#
#    ...            job_s  kind_s     cdx_index_ss  \
# 0  ...  bl-your_stories  warcs   [data-heritrix]
# 1  ...  bl-your_stories  warcs   [data-heritrix]
#
#                                                                                                  id  \
# 0  hdfs://hdfs:54310/1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814093821.warc.gz
# 1  hdfs://hdfs:54310/1_data/npld/webrecorder/bl-your_stories/warcs/www.bl.uk-20150814094134.warc.gz
#
#          timestamp_dt                     file_ext_s permissions_s  \
# 0 2016-12-30 11:59:00  .bl.uk-20150814093821.warc.gz  -rw-r--r--
# 1 2016-12-30 11:59:00  .bl.uk-20150814094134.warc.gz  -rw-r--r--
#
#           refresh_date_dt _query_ score
# 0 2021-02-11 08:17:08.836 NaN      0
# 1 2021-02-11 08:17:08.836 NaN      0
#
# [2 rows x 26 columns]
