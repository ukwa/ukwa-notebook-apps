# %% [markdown]
# # Archived Holdings - Access Status
#
# We can use the Tracking Database check the WARC index status.
#
# The CDX index status can be broken down by day using the following facet query (taking advantage of [Solr's JSON Facet API](https://lucene.apache.org/solr/guide/8_4/json-facet-api.html)).

# %%
import json
import requests
import pandas as pd

headers = {'content-type': "application/json" }

json_facet = {
    # Primary facet is by date - here we break down the last month(s) into days
    'facet': {
        'dates' : { 
            'type' : 'range', 
            'field' : 'timestamp_dt', 
            'start' : "NOW/MONTH-1MONTH",
            'end' : "NOW/MONTH+32DAY", 
#            'start' : "NOW/MONTH-10YEAR",
#            'end' : "NOW/MONTH+1MONTH", 
            'gap' : "+1DAY", 
#            'gap' : "+1MONTH", 
            # For each day, we facet:
            'facet': { 
                'stream': { 
                    'type': 'terms', 
                    "field": "stream_s", 
                    'missing': True,
                    'facet': { 
                        'cdx_status': { 
                            'type': 'terms', 
                            "field": "cdx_index_ss", 
                            'missing': True,
                            'facet' : {
                                'bytes': 'sum(file_size_l)'
                            }
                        }
                    }
                }
            }
        } 
    }
}


params = {
  'q': 'kind_s:"warcs"',
  'rows': 0
}

r = requests.post("http://solr8.api.wa.bl.uk/solr/tracking/select", params=params, data=json.dumps(json_facet), headers=headers)

if r.status_code != 200:
    print(r.text)

from solr.solr_facet_helper import flatten_solr_buckets

df = pd.DataFrame(flatten_solr_buckets(r.json()['facets']))
# Filter empty rows:
df=df[df['count'] != 0]

# Add compound column:
df['status'] = df.apply(lambda row: "%s, %s" % (row.stream, row.cdx_status), axis=1)

df
# Out:
#                     dates    stream     cdx_status  count         bytes  \
# 0    2020-12-01T00:00:00Z  frequent  data-heritrix    180  1.777719e+11
# 3    2020-12-02T00:00:00Z  frequent  data-heritrix    176  1.713391e+11
# 6    2020-12-03T00:00:00Z  frequent  data-heritrix    171  1.689248e+11
# 9    2020-12-04T00:00:00Z  frequent  data-heritrix    177  1.746900e+11
# 12   2020-12-05T00:00:00Z  frequent  data-heritrix    189  1.849292e+11
# 15   2020-12-06T00:00:00Z  frequent  data-heritrix    170  1.662981e+11
# 18   2020-12-07T00:00:00Z  frequent  data-heritrix    161  1.583262e+11
# 21   2020-12-08T00:00:00Z  frequent  data-heritrix    176  1.761106e+11
# 24   2020-12-09T00:00:00Z  frequent  data-heritrix    185  1.823975e+11
# 27   2020-12-10T00:00:00Z  frequent  data-heritrix    218  2.172997e+11
# 30   2020-12-11T00:00:00Z  frequent  data-heritrix    345  3.433304e+11
# 33   2020-12-12T00:00:00Z  frequent  data-heritrix    347  3.426047e+11
# 36   2020-12-13T00:00:00Z  frequent  data-heritrix     99  9.889127e+10
# 40   2020-12-15T00:00:00Z  frequent  data-heritrix    342  3.587965e+11
# 43   2020-12-16T00:00:00Z  frequent  data-heritrix    835  8.697617e+11
# 46   2020-12-17T00:00:00Z  frequent  data-heritrix    299  3.002280e+11
# 49   2020-12-18T00:00:00Z  frequent  data-heritrix    312  3.143996e+11
# 52   2020-12-19T00:00:00Z  frequent  data-heritrix    339  3.378270e+11
# 55   2020-12-20T00:00:00Z  frequent  data-heritrix    302  3.034929e+11
# 58   2020-12-21T00:00:00Z  frequent  data-heritrix    303  3.014039e+11
# 61   2020-12-22T00:00:00Z  frequent  data-heritrix    301  2.997292e+11
# 64   2020-12-23T00:00:00Z  frequent  data-heritrix    323  3.229383e+11
# 67   2020-12-24T00:00:00Z  frequent  data-heritrix    322  3.219155e+11
# 70   2020-12-25T00:00:00Z  frequent  data-heritrix    346  3.500674e+11
# 73   2020-12-26T00:00:00Z  frequent  data-heritrix    338  3.412768e+11
# 76   2020-12-27T00:00:00Z  frequent  data-heritrix    321  3.226253e+11
# 79   2020-12-28T00:00:00Z  frequent  data-heritrix    304  3.035625e+11
# 82   2020-12-29T00:00:00Z  frequent  data-heritrix    313  3.140709e+11
# 85   2020-12-30T00:00:00Z  frequent  data-heritrix    296  2.976264e+11
# 88   2020-12-31T00:00:00Z  frequent  data-heritrix    328  3.293219e+11
# 91   2021-01-01T00:00:00Z  frequent  data-heritrix    325  3.234827e+11
# 94   2021-01-02T00:00:00Z  frequent  data-heritrix    302  3.029943e+11
# 97   2021-01-03T00:00:00Z  frequent  data-heritrix    294  2.927709e+11
# 100  2021-01-04T00:00:00Z  frequent  data-heritrix    304  3.009945e+11
# 103  2021-01-05T00:00:00Z  frequent  data-heritrix    293  2.910120e+11
# 106  2021-01-06T00:00:00Z  frequent  data-heritrix    309  3.033818e+11
# 109  2021-01-07T00:00:00Z  frequent  data-heritrix    257  2.582428e+11
# 112  2021-01-08T00:00:00Z  frequent  data-heritrix    276  2.685336e+11
# 115  2021-01-09T00:00:00Z  frequent  data-heritrix    260  2.590008e+11
#
#                       status
# 0    frequent, data-heritrix
# 3    frequent, data-heritrix
# 6    frequent, data-heritrix
# 9    frequent, data-heritrix
# 12   frequent, data-heritrix
# 15   frequent, data-heritrix
# 18   frequent, data-heritrix
# 21   frequent, data-heritrix
# 24   frequent, data-heritrix
# 27   frequent, data-heritrix
# 30   frequent, data-heritrix
# 33   frequent, data-heritrix
# 36   frequent, data-heritrix
# 40   frequent, data-heritrix
# 43   frequent, data-heritrix
# 46   frequent, data-heritrix
# 49   frequent, data-heritrix
# 52   frequent, data-heritrix
# 55   frequent, data-heritrix
# 58   frequent, data-heritrix
# 61   frequent, data-heritrix
# 64   frequent, data-heritrix
# 67   frequent, data-heritrix
# 70   frequent, data-heritrix
# 73   frequent, data-heritrix
# 76   frequent, data-heritrix
# 79   frequent, data-heritrix
# 82   frequent, data-heritrix
# 85   frequent, data-heritrix
# 88   frequent, data-heritrix
# 91   frequent, data-heritrix
# 94   frequent, data-heritrix
# 97   frequent, data-heritrix
# 100  frequent, data-heritrix
# 103  frequent, data-heritrix
# 106  frequent, data-heritrix
# 109  frequent, data-heritrix
# 112  frequent, data-heritrix
# 115  frequent, data-heritrix

# %% [markdown]
# Which can be used to build a simple visualisation:

# %%
import altair as alt

alt.Chart(df).mark_bar(size=6).encode(
    x='dates:T',
    y='count',
    color='status',
    tooltip=[alt.Tooltip('dates:T', format='%A, %e %B %Y'), 'stream', 'cdx_status', 'count', 'bytes']
).properties(width=600).interactive()
# Out:
# alt.Chart(...)
